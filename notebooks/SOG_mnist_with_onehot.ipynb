# %%
import torch
import torch.utils
from torchvision import datasets, transforms
import torchvision.utils
import numpy as np
import matplotlib.pyplot as plt

# %%
n_g = 1  # size of the latent gaussian variable
n_b = 0  # size of the latent binary variable
n_o = 10  # size of the latent one-hot variable

batch_size = 64  # samples of data distribution at each iteration
latent_batch_size = np.power(32, n_g) * np.power(2, n_b) * n_o  # number of possible latent codes to try for each sample

n_epochs = 300

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

torch.manual_seed(42)
np.random.seed(42)

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True, drop_last=True)

# %%
class LatentCodeDistribution():
    def __init__(self, n_g, n_b, n_o):
        self.m_n = torch.distributions.multivariate_normal.MultivariateNormal(torch.zeros(n_g), torch.eye(n_g))
        self.m_b = torch.distributions.bernoulli.Bernoulli(torch.tensor([0.5]))
        self.m_o = torch.distributions.one_hot_categorical.OneHotCategorical(torch.ones(n_o)/n_o)
        
        self.n_g, self.n_b, self.n_o = n_g, n_b, n_o
        
    def sample(self, n_samples):
        gaussian_samples = self.m_n.sample([n_samples],)
        bernoulli_samples = self.m_b.sample([n_samples, self.n_b]).squeeze(-1)  # there is a singleton dimension that has to be removed
        one_hot_samples = self.m_o.sample([n_samples]) if self.n_o != 0 else torch.zeros([n_samples, 0])
        
        return torch.cat([gaussian_samples, bernoulli_samples, one_hot_samples], dim=1)

# %%
# D_in is input dimension;
# H is hidden dimension;
# D_out is output dimension.

D_in, H, D_out = n_g + n_b + n_o, 100, 28 * 28

model = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
).to(device)

# %%
def row_wise_repeat(mat, n_rep):
    """
    pytorch equivalent of np.repeat
    """
    return torch.cat([row.repeat(n_rep, 1) for row in mat.split(split_size=1)])

# %%
params = list(model.parameters())
    
optimizer = torch.optim.Adam(params, betas=(0.5, 0.999))
loss_fn = torch.nn.L1Loss(reduction='none')

# %%
loss_log = []
latent_code_dist = LatentCodeDistribution(n_g, n_b, n_o)

for epoch in range(1, n_epochs + 1):
    current_epoch_losses = []
    
    for batch_idx, (data, _) in enumerate(train_loader):
        if batch_idx % 100 == 0:
            print('Iteration: {}'.format(batch_idx))
        data = data.to(device) 
        data = data.reshape(data.shape[0], -1)  # flatten the image
        
        x_train = latent_code_dist.sample(latent_batch_size).to(device)
        y_train = data.repeat(latent_batch_size, 1)
        
        y_pred = row_wise_repeat(model(x_train), batch_size)

        loss_all_modes = loss_fn(y_pred, y_train)
        

        # Zero the gradients before running the backward pass.
        optimizer.zero_grad()
        
        selective_loss = loss_all_modes.mean(dim=1).reshape(latent_batch_size, batch_size).min(dim=0)[0].sum()
        selective_loss.backward()        
        
        current_epoch_losses.append(selective_loss)
        
        optimizer.step()
    
    loss_log.append(torch.tensor(current_epoch_losses).mean().detach().numpy())
    
    if True:  # if epoch % 10 == 0:
        print('Epoch: {} / Loss: {:.2f}'.format(epoch, loss_log[-1]) + '\n' + '=' * 20)
# Out:
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 1 / Loss: 16.20
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 2 / Loss: 16.20
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 3 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 4 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 5 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 6 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 7 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 8 / Loss: 16.18
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 9 / Loss: 16.17
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 10 / Loss: 16.16
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 11 / Loss: 16.16
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 13 / Loss: 16.15
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 14 / Loss: 16.15
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 15 / Loss: 16.15
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 16 / Loss: 16.15
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 17 / Loss: 16.15
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 18 / Loss: 16.14
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 19 / Loss: 16.14
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 20 / Loss: 16.14
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 21 / Loss: 16.14
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 22 / Loss: 16.14
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 23 / Loss: 16.13
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 24 / Loss: 16.13
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 25 / Loss: 16.12
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 26 / Loss: 16.13
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 27 / Loss: 16.12
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 28 / Loss: 16.12
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 29 / Loss: 16.11
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 30 / Loss: 16.11
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 31 / Loss: 16.11
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 32 / Loss: 16.12
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 33 / Loss: 16.11
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 34 / Loss: 16.11
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 35 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 36 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 37 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 38 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 39 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 40 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 41 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 42 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 43 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 44 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 45 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 46 / Loss: 16.10
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 47 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 48 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 49 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 50 / Loss: 16.09
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 51 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 52 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 53 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 54 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 55 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 56 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 57 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 58 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 59 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 60 / Loss: 16.08
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 61 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 62 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 63 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 64 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 65 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 66 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 67 / Loss: 16.07
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 68 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 69 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 70 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 71 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 72 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 73 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 74 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 75 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 76 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 77 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 78 / Loss: 16.06
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 79 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 80 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 81 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 82 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 83 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 84 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 85 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 86 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 87 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 88 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 89 / Loss: 16.05
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 90 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 91 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 92 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 93 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 94 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 95 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 96 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 97 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 98 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 99 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 100 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 101 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 102 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 103 / Loss: 16.04
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 104 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 105 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 106 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 107 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 108 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 109 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 110 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 111 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 112 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 113 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 114 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 115 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 116 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 117 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 118 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 119 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 120 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 121 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 122 / Loss: 16.03
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 123 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 124 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 125 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 126 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 127 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 128 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 129 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 130 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 131 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 132 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 133 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 134 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 135 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 136 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 137 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 138 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 139 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 140 / Loss: 16.02
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 141 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 142 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 143 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 144 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 145 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 146 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 147 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 148 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 149 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 150 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 151 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 152 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 153 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 154 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 155 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 156 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 157 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 158 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 159 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 160 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 161 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 162 / Loss: 16.01
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 163 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 164 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 165 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 166 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 167 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 168 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 169 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 170 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 171 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 172 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 173 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 174 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 175 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 176 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 177 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 178 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 179 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 180 / Loss: 15.99
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 181 / Loss: 16.00
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Epoch: 182 / Loss: 15.99
# ====================
# Iteration: 0
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-d0fbb9ed7ff1> in <module>
#      23
#      24         selective_loss = loss_all_modes.mean(dim=1).reshape(latent_batch_size, batch_size).min(dim=0)[0].sum()
# ---> 25         selective_loss.backward()
#      26
#      27         current_epoch_losses.append(selective_loss)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
latent_code_dist.sample(10)

# %%
plt.figure()
plt.title('Loss vs Epochs Passed')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(range(len(loss_log)), loss_log)
plt.show()

# %%
from scipy.stats import norm
import itertools

grid_width = 8

if n_g == 2 and n_b == 0 and n_o == 0:
    x1 = np.linspace(0.02, 0.98, grid_width)
    x2 = np.linspace(0.02, 0.98, grid_width)
    x1, x2 = norm.ppf(x1), norm.ppf(x2)  # apply inverse normal cdf to distribute codes equally across the distribution

    xv1, xv2 = np.meshgrid(x1, x2)
    
    # turn into a batch
    xv1 = xv1.reshape(-1, 1)
    xv2 = xv2.reshape(-1, 1)

elif n_g == 1 and n_b != 0 and n_o == 0:
    x1 = np.linspace(0.02, 0.98, grid_width)
    x2 = np.array(list(itertools.product([0, 1], repeat=n_b)))
    
    xv1 = np.repeat(x1[:, None], np.power(2, n_b), axis=0)
    xv2 = np.tile(x2, (grid_width, 1))
        
elif n_g == 1 and n_b == 0 and n_o != 0:
    x1 = np.linspace(0.02, 0.98, grid_width)
    x1 = norm.ppf(x1)  # apply inverse normal cdf to distribute codes equally across the distribution
    
    x2 = np.linspace(0, n_o - 1 , n_o, dtype=np.int32)
    
    xv1, xv2 = np.meshgrid(x1, x2)
    
    # turn into a batch
    xv1 = xv1.reshape(-1, 1)
    xv2 = xv2.reshape(-1, 1)
    
    xv2 = xv2.flatten()
    xv2 = np.eye(n_o)[xv2]
        
else:
    raise Exception('Cannot visualize for n_g = {}, n_b = {}, n_o = {}'.format(n_g, n_b, n_o))

x_test = torch.from_numpy(np.hstack([xv1, xv2])).float().to(device)
y_pred = model(x_test).detach().cpu().reshape(-1, 1, 28, 28)
    
plt.figure(dpi=300)
img = torchvision.utils.make_grid(y_pred, nrow=grid_width, padding=2, normalize=False, range=None, scale_each=False, pad_value=0)
plt.imshow(np.transpose(img, (1,2,0)))
                            
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

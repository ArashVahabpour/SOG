# %%
import torch
import torch.utils
from torchvision import datasets, transforms
import torchvision.utils
import numpy as np
import matplotlib.pyplot as plt

# %%
n_latent_gaussian = 2  # size of the latent gaussian variable

batch_size = 64  # samples of data distribution at each iteration
latent_batch_size = 1024  # number of possible latent codes to try for each sample

n_epochs = 300

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

torch.manual_seed(42)
np.random.seed(42)

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True, drop_last=True)

# %%
def sample_latent_codes(n_latent_samples):
    gaussian_samples = np.random.randn(n_latent_samples, n_latent_gaussian)
    return torch.from_numpy(gaussian_samples).float()

# %%
# D_in is input dimension;
# H is hidden dimension;
# D_out is output dimension.

D_in, H, D_out = n_latent_gaussian + n_latent_one_hot, 100, 28 * 28

model = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
).to(device)

# %%
params = list(model.parameters())
    
optimizer = torch.optim.Adam(params, betas=(0.5, 0.999))
loss_fn = torch.nn.L1Loss(reduction='none')

# %%
loss_log = []

for epoch in range(1, n_epochs + 1):
    current_epoch_losses = []
    
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device) 
        data = data.reshape(data.shape[0], -1)  # flatten the image
        
        x_train = sample_latent_codes(batch_size * latent_batch_size).to(device)
        y_train = data.repeat(latent_batch_size, 1)
        y_pred = model(x_train)

        loss_all_modes = loss_fn(y_pred, y_train)

        # Zero the gradients before running the backward pass.
        optimizer.zero_grad()
        
        selective_loss = loss_all_modes.mean(dim=1).reshape(latent_batch_size, batch_size).min(dim=0)[0].sum()
        selective_loss.backward()
        
        current_epoch_losses.append(selective_loss)
        
        optimizer.step()
    
    loss_log.append(torch.tensor(current_epoch_losses).mean().detach().numpy())
    
    if True:  # if epoch % 10 == 0:
        print('Epoch: {} / Loss: {:.2f}'.format(epoch, loss_log[-1]))
# Out:
# Epoch: 1 / Loss: 26.31
# Epoch: 2 / Loss: 26.05
# Epoch: 3 / Loss: 26.02
# Epoch: 4 / Loss: 26.01
# Epoch: 5 / Loss: 26.00
# Epoch: 6 / Loss: 24.10
# Epoch: 7 / Loss: 22.43
# Epoch: 8 / Loss: 21.17
# Epoch: 9 / Loss: 20.03
# Epoch: 10 / Loss: 19.59
# Epoch: 11 / Loss: 19.19
# Epoch: 12 / Loss: 18.74
# Epoch: 13 / Loss: 18.38
# Epoch: 14 / Loss: 18.11
# Epoch: 15 / Loss: 17.90
# Epoch: 16 / Loss: 17.73
# Epoch: 17 / Loss: 17.57
# Epoch: 18 / Loss: 17.42
# Epoch: 19 / Loss: 17.30
# Epoch: 20 / Loss: 17.18
# Epoch: 21 / Loss: 17.08
# Epoch: 22 / Loss: 16.99
# Epoch: 23 / Loss: 16.91
# Epoch: 24 / Loss: 16.83
# Epoch: 25 / Loss: 16.76
# Epoch: 26 / Loss: 16.70
# Epoch: 27 / Loss: 16.64
# Epoch: 28 / Loss: 16.60
# Epoch: 29 / Loss: 16.55
# Epoch: 30 / Loss: 16.51
# Epoch: 31 / Loss: 16.48
# Epoch: 32 / Loss: 16.44
# Epoch: 33 / Loss: 16.41
# Epoch: 34 / Loss: 16.38
# Epoch: 35 / Loss: 16.35
# Epoch: 36 / Loss: 16.32
# Epoch: 37 / Loss: 16.29
# Epoch: 38 / Loss: 16.27
# Epoch: 39 / Loss: 16.24
# Epoch: 40 / Loss: 16.22
# Epoch: 41 / Loss: 16.19
# Epoch: 42 / Loss: 16.17
# Epoch: 43 / Loss: 16.14
# Epoch: 44 / Loss: 16.13
# Epoch: 45 / Loss: 16.11
# Epoch: 46 / Loss: 16.09
# Epoch: 47 / Loss: 16.08
# Epoch: 48 / Loss: 16.06
# Epoch: 49 / Loss: 16.05
# Epoch: 50 / Loss: 16.04
# Epoch: 51 / Loss: 16.02
# Epoch: 52 / Loss: 16.02
# Epoch: 53 / Loss: 16.00
# Epoch: 54 / Loss: 15.99
# Epoch: 55 / Loss: 15.98
# Epoch: 56 / Loss: 15.97
# Epoch: 57 / Loss: 15.96
# Epoch: 58 / Loss: 15.95
# Epoch: 59 / Loss: 15.95
# Epoch: 60 / Loss: 15.93
# Epoch: 61 / Loss: 15.93
# Epoch: 62 / Loss: 15.92
# Epoch: 63 / Loss: 15.91
# Epoch: 64 / Loss: 15.90
# Epoch: 65 / Loss: 15.88
# Epoch: 66 / Loss: 15.88
# Epoch: 67 / Loss: 15.88
# Epoch: 68 / Loss: 15.87
# Epoch: 69 / Loss: 15.86
# Epoch: 70 / Loss: 15.85
# Epoch: 71 / Loss: 15.85
# Epoch: 72 / Loss: 15.84
# Epoch: 73 / Loss: 15.83
# Epoch: 74 / Loss: 15.82
# Epoch: 75 / Loss: 15.81
# Epoch: 76 / Loss: 15.81
# Epoch: 77 / Loss: 15.80
# Epoch: 78 / Loss: 15.79
# Epoch: 79 / Loss: 15.79
# Epoch: 80 / Loss: 15.78
# Epoch: 81 / Loss: 15.78
# Epoch: 82 / Loss: 15.77
# Epoch: 83 / Loss: 15.77
# Epoch: 84 / Loss: 15.76
# Epoch: 85 / Loss: 15.76
# Epoch: 86 / Loss: 15.75
# Epoch: 87 / Loss: 15.74
# Epoch: 88 / Loss: 15.74
# Epoch: 89 / Loss: 15.74
# Epoch: 90 / Loss: 15.73
# Epoch: 91 / Loss: 15.73
# Epoch: 92 / Loss: 15.72
# Epoch: 93 / Loss: 15.72
# Epoch: 94 / Loss: 15.72
# Epoch: 95 / Loss: 15.71
# Epoch: 96 / Loss: 15.71
# Epoch: 97 / Loss: 15.71
# Epoch: 98 / Loss: 15.70
# Epoch: 99 / Loss: 15.70
# Epoch: 100 / Loss: 15.69
# Epoch: 101 / Loss: 15.70
# Epoch: 102 / Loss: 15.69
# Epoch: 103 / Loss: 15.69
# Epoch: 104 / Loss: 15.68
# Epoch: 105 / Loss: 15.68
# Epoch: 106 / Loss: 15.68
# Epoch: 107 / Loss: 15.67
# Epoch: 108 / Loss: 15.67
# Epoch: 109 / Loss: 15.67
# Epoch: 110 / Loss: 15.66
# Epoch: 111 / Loss: 15.66
# Epoch: 112 / Loss: 15.66
# Epoch: 113 / Loss: 15.65
# Epoch: 114 / Loss: 15.65
# Epoch: 115 / Loss: 15.65
# Epoch: 116 / Loss: 15.65
# Epoch: 117 / Loss: 15.65
# Epoch: 118 / Loss: 15.64
# Epoch: 119 / Loss: 15.64
# Epoch: 120 / Loss: 15.64
# Epoch: 121 / Loss: 15.63
# Epoch: 122 / Loss: 15.63
# Epoch: 123 / Loss: 15.64
# Epoch: 124 / Loss: 15.63
# Epoch: 125 / Loss: 15.62
# Epoch: 126 / Loss: 15.62
# Epoch: 127 / Loss: 15.62
# Epoch: 128 / Loss: 15.62
# Epoch: 129 / Loss: 15.62
# Epoch: 130 / Loss: 15.61
# Epoch: 131 / Loss: 15.61
# Epoch: 132 / Loss: 15.61
# Epoch: 133 / Loss: 15.61
# Epoch: 134 / Loss: 15.60
# Epoch: 135 / Loss: 15.60
# Epoch: 136 / Loss: 15.60
# Epoch: 137 / Loss: 15.60
# Epoch: 138 / Loss: 15.60
# Epoch: 139 / Loss: 15.59
# Epoch: 140 / Loss: 15.59
# Epoch: 141 / Loss: 15.59
# Epoch: 142 / Loss: 15.59
# Epoch: 143 / Loss: 15.59
# Epoch: 144 / Loss: 15.58
# Epoch: 145 / Loss: 15.58
# Epoch: 146 / Loss: 15.58
# Epoch: 147 / Loss: 15.58
# Epoch: 148 / Loss: 15.58
# Epoch: 149 / Loss: 15.57
# Epoch: 150 / Loss: 15.57
# Epoch: 151 / Loss: 15.57
# Epoch: 152 / Loss: 15.57
# Epoch: 153 / Loss: 15.57
# Epoch: 154 / Loss: 15.57
# Epoch: 155 / Loss: 15.56
# Epoch: 156 / Loss: 15.56
# Epoch: 157 / Loss: 15.56
# Epoch: 158 / Loss: 15.56
# Epoch: 159 / Loss: 15.56
# Epoch: 160 / Loss: 15.56
# Epoch: 161 / Loss: 15.56
# Epoch: 162 / Loss: 15.55
# Epoch: 163 / Loss: 15.55
# Epoch: 164 / Loss: 15.55
# Epoch: 165 / Loss: 15.55
# Epoch: 166 / Loss: 15.55
# Epoch: 167 / Loss: 15.55
# Epoch: 168 / Loss: 15.55
# Epoch: 169 / Loss: 15.54
# Epoch: 170 / Loss: 15.54
# Epoch: 171 / Loss: 15.54
# Epoch: 172 / Loss: 15.54
# Epoch: 173 / Loss: 15.54
# Epoch: 174 / Loss: 15.54
# Epoch: 175 / Loss: 15.54
# Epoch: 176 / Loss: 15.53
# Epoch: 177 / Loss: 15.54
# Epoch: 178 / Loss: 15.53
# Epoch: 179 / Loss: 15.53
# Epoch: 180 / Loss: 15.53
# Epoch: 181 / Loss: 15.53
# Epoch: 182 / Loss: 15.53
# Epoch: 183 / Loss: 15.53
# Epoch: 184 / Loss: 15.53
# Epoch: 185 / Loss: 15.53
# Epoch: 186 / Loss: 15.52
# Epoch: 187 / Loss: 15.52
# Epoch: 188 / Loss: 15.52
# Epoch: 189 / Loss: 15.52
# Epoch: 190 / Loss: 15.52
# Epoch: 191 / Loss: 15.52
# Epoch: 192 / Loss: 15.52
# Epoch: 193 / Loss: 15.52
# Epoch: 194 / Loss: 15.52
# Epoch: 195 / Loss: 15.52
# Epoch: 196 / Loss: 15.51
# Epoch: 197 / Loss: 15.51
# Epoch: 198 / Loss: 15.51
# Epoch: 199 / Loss: 15.51
# Epoch: 200 / Loss: 15.51
# Epoch: 201 / Loss: 15.51
# Epoch: 202 / Loss: 15.51
# Epoch: 203 / Loss: 15.50
# Epoch: 204 / Loss: 15.51
# Epoch: 205 / Loss: 15.51
# Epoch: 206 / Loss: 15.50
# Epoch: 207 / Loss: 15.50
# Epoch: 208 / Loss: 15.50
# Epoch: 209 / Loss: 15.50
# Epoch: 210 / Loss: 15.50
# Epoch: 211 / Loss: 15.50
# Epoch: 212 / Loss: 15.50
# Epoch: 213 / Loss: 15.50
# Epoch: 214 / Loss: 15.49
# Epoch: 215 / Loss: 15.50
# Epoch: 216 / Loss: 15.49
# Epoch: 217 / Loss: 15.49
# Epoch: 218 / Loss: 15.49
# Epoch: 219 / Loss: 15.49
# Epoch: 220 / Loss: 15.49
# Epoch: 221 / Loss: 15.49
# Epoch: 222 / Loss: 15.49
# Epoch: 223 / Loss: 15.49
# Epoch: 224 / Loss: 15.49
# Epoch: 225 / Loss: 15.49
# Epoch: 226 / Loss: 15.49
# Epoch: 227 / Loss: 15.48
# Epoch: 228 / Loss: 15.48
# Epoch: 229 / Loss: 15.49
# Epoch: 230 / Loss: 15.48
# Epoch: 231 / Loss: 15.48
# Epoch: 232 / Loss: 15.48
# Epoch: 233 / Loss: 15.48
# Epoch: 234 / Loss: 15.48
# Epoch: 235 / Loss: 15.48
# Epoch: 236 / Loss: 15.47
# Epoch: 237 / Loss: 15.48
# Epoch: 238 / Loss: 15.47
# Epoch: 239 / Loss: 15.48
# Epoch: 240 / Loss: 15.48
# Epoch: 241 / Loss: 15.47
# Epoch: 242 / Loss: 15.47
# Epoch: 243 / Loss: 15.47
# Epoch: 244 / Loss: 15.47
# Epoch: 245 / Loss: 15.47
# Epoch: 246 / Loss: 15.47
# Epoch: 247 / Loss: 15.47
# Epoch: 248 / Loss: 15.46
# Epoch: 249 / Loss: 15.47
# Epoch: 250 / Loss: 15.46
# Epoch: 251 / Loss: 15.46
# Epoch: 252 / Loss: 15.46
# Epoch: 253 / Loss: 15.46
# Epoch: 254 / Loss: 15.47
# Epoch: 255 / Loss: 15.46
# Epoch: 256 / Loss: 15.46
# Epoch: 257 / Loss: 15.46
# Epoch: 258 / Loss: 15.46
# Epoch: 259 / Loss: 15.46
# Epoch: 260 / Loss: 15.46
# Epoch: 261 / Loss: 15.45
# Epoch: 262 / Loss: 15.46
# Epoch: 263 / Loss: 15.46
# Epoch: 264 / Loss: 15.45
# Epoch: 265 / Loss: 15.45
# Epoch: 266 / Loss: 15.45
# Epoch: 267 / Loss: 15.45
# Epoch: 268 / Loss: 15.45
# Epoch: 269 / Loss: 15.45
# Epoch: 270 / Loss: 15.45
# Epoch: 271 / Loss: 15.45
# Epoch: 272 / Loss: 15.45
# Epoch: 273 / Loss: 15.45
# Epoch: 274 / Loss: 15.44
# Epoch: 275 / Loss: 15.44
# Epoch: 276 / Loss: 15.44
# Epoch: 277 / Loss: 15.44
# Epoch: 278 / Loss: 15.44
# Epoch: 279 / Loss: 15.44
# Epoch: 280 / Loss: 15.44
# Epoch: 281 / Loss: 15.44
# Epoch: 282 / Loss: 15.44
# Epoch: 283 / Loss: 15.44
# Epoch: 284 / Loss: 15.44
# Epoch: 285 / Loss: 15.43
# Epoch: 286 / Loss: 15.43
# Epoch: 287 / Loss: 15.43
# Epoch: 288 / Loss: 15.43
# Epoch: 289 / Loss: 15.43
# Epoch: 290 / Loss: 15.43
# Epoch: 291 / Loss: 15.43
# Epoch: 292 / Loss: 15.43
# Epoch: 293 / Loss: 15.43
# Epoch: 294 / Loss: 15.43
# Epoch: 295 / Loss: 15.43
# Epoch: 296 / Loss: 15.43
# Epoch: 297 / Loss: 15.42
# Epoch: 298 / Loss: 15.42
# Epoch: 299 / Loss: 15.42
# Epoch: 300 / Loss: 15.42

# %%
plt.figure()
plt.title('Loss vs Epochs Passed')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(range(len(loss_log)), loss_log)
plt.show()

# %%
from scipy.stats import norm

grid_width = 10

x1 = np.linspace(0.02, 0.98, grid_width)
x2 = np.linspace(0.02, 0.98, grid_width)
x1, x2 = norm.ppf(x1), norm.ppf(x2)  # apply inverse normal cdf to distribute codes equally across the distribution

xv1, xv2 = np.meshgrid(x1, x2)

x_test = torch.from_numpy(np.hstack([xv1.reshape(-1, 1), xv2.reshape(-1, 1)])).float().to(device)
y_pred = model(x_test).detach().cpu().reshape(-1, 1, 28, 28)

plt.figure(dpi=300)
img = torchvision.utils.make_grid(y_pred, nrow=grid_width, padding=2, normalize=False, range=None, scale_each=False, pad_value=0)
plt.imshow(np.transpose(img, (1,2,0)))
                            
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
